# %%
# import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

#set a nicer default color palette
sns.set_palette(sns.color_palette("hls", 4))
style.use("seaborn-whitegrid") #use this style..


plt.rcParams['figure.figsize'] = [10.0, 5.0]
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 14
plt.rcParams['legend.fontsize'] = 'small'
plt.rcParams['axes.titlesize'] = 22
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

#covid data
covid_data_file = "owid-covid-data.csv"

#read the data 
data = pd.read_csv(covid_data_file, sep=',')

data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
#check the shape
data.shape
# Out:
# (103612, 60)

# %%
#check the nulls
data.isnull().sum()
# Out:
# iso_code                                      0
# continent                                  4831
# location                                      0
# date                                          0
# total_cases                                4013
# new_cases                                  4016
# new_cases_smoothed                         5026
# total_deaths                              14271
# new_deaths                                14115
# new_deaths_smoothed                        5026
# total_cases_per_million                    4542
# new_cases_per_million                      4545
# new_cases_smoothed_per_million             5550
# total_deaths_per_million                  14787
# new_deaths_per_million                    14631
# new_deaths_smoothed_per_million            5550
# reproduction_rate                         19905
# icu_patients                              92887
# icu_patients_per_million                  92887
# hosp_patients                             90664
# ...

# %%
data.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
#if the data is updated this will need to change
mask_latest = data["date"] == "2021-07-19"

#get all observations with the latest date
latest_total = data.loc[mask_latest, ["continent", "total_cases", "total_deaths"]]

#sum totals per continent 
continent_sum = latest_total.groupby(['continent']).sum() 

continent_sum["total_cases"] = continent_sum["total_cases"] / 1000
continent_sum["total_deaths"] = continent_sum["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

ax = continent_sum.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("Continents")
ax.legend(labels = labels)

plt.show()

# %%
#create country breakdown per continent - AFRICA
africa_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = africa_total["continent"] == "Africa"

africa = africa_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
africa = africa.set_index('iso_code')

africa["total_cases"] = africa["total_cases"] / 1000
africa["total_deaths"] = africa["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = africa.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("Africa - Country ISO")
ax.legend(labels = labels)

plt.show()

# %%
# ASIA
asia_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = asia_total["continent"] == "Asia"

asia = asia_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
asia = asia.set_index('iso_code')

asia["total_cases"] = asia["total_cases"] / 1000
asia["total_deaths"] = asia["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = asia.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("Asia - Country ISO")
ax.legend(labels = labels)

plt.show()

# %%
# EUROPE
europe_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = europe_total["continent"] == "Europe"

europe = europe_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
europe = europe.set_index('iso_code')

europe["total_cases"] = europe["total_cases"] / 1000
europe["total_deaths"] = europe["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = europe.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("Europe - Country ISO")
ax.legend(labels = labels)

plt.show()

# %%
# North America
namerica_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = namerica_total["continent"] == "North America"

namerica = namerica_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
namerica = namerica.set_index('iso_code')

namerica["total_cases"] = namerica["total_cases"] / 1000
namerica["total_deaths"] = namerica["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = namerica.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("North America - Country ISO")
ax.legend(labels = labels)

plt.show()

# %%
# Oceania
oceania_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = oceania_total["continent"] == "Oceania"

oceania = oceania_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
oceania = oceania.set_index('iso_code')

oceania["total_cases"] = oceania["total_cases"] / 1000
oceania["total_deaths"] = oceania["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = oceania.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("Oceania - Country ISO")
ax.legend(labels = labels)

plt.show()

# %%
# South America
samerica_total = data.loc[mask_latest, ["iso_code","continent", "total_cases", "total_deaths"]]

mask_continent = samerica_total["continent"] == "South America"

samerica = samerica_total.loc[mask_continent, ["iso_code", "total_cases", "total_deaths"] ]

#set the index to iso code
samerica = samerica.set_index('iso_code')

samerica["total_cases"] = samerica["total_cases"] / 1000
samerica["total_deaths"] = samerica["total_deaths"] / 1000

labels = ["Total Cases", "Total Deaths"]

#resize the tick label
plt.rcParams['xtick.labelsize'] = 9

ax = samerica.plot.bar()
ax.set_ylabel("Cases (x1000)")
ax.set_xlabel("South America - Country ISO")
ax.legend(labels = labels)

plt.show()
